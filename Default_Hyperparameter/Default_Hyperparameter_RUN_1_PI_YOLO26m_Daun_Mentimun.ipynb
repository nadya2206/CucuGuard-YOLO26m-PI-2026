# %% [markdown]
# ### PI NADYA PUTRI NUR ALETTA (51423061)
# ### DETEKSI PENYAKIT DAUN MENTIMUN MENGGUNAKAN MODEL YOLO26m

# %% [markdown]
# #### BAGIAN 1: Verifikasi GPU dan Install Dependencies

# %%
# 1. Cek apakah GPU NVIDIA sudah aktif
# !nvidia-smi
# Out:
# Sun Jun 28 10:15:44 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# 2. Install library Ultralytics untuk eksekusi YOLO dan Roboflow untuk mengambil data
# !pip install ultralytics roboflow
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.80-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 3.6 MB/s eta 0:00:00
# Collecting roboflow
#   Downloading roboflow-1.3.10-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2026.5.20)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.0)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.3 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.3)
# Requirement already satisfied: requests_toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typer<0.26,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.25.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (8.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)
# Downloading ultralytics-8.4.80-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.7 MB/s eta 0:00:00
# Downloading roboflow-1.3.10-py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 29.2 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.0 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.0 MB/s eta 0:00:00
# Downloading pi_heif-1.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 23.3 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 134.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: pillow-avif-plugin, filetype, pi-heif, opencv-python-headless, idna, roboflow, ultralytics-thop, ultralytics
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.18
#     Uninstalling idna-3.18:
#       Successfully uninstalled idna-3.18
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.4.0 pillow-avif-plugin-1.5.5 roboflow-1.3.10 ultralytics-8.4.80 ultralytics-thop-2.0.20

# %% [markdown]
# #### BAGIAN 2: Mengunduh Dataset dari Roboflow

# %%
from roboflow import Roboflow

# Snippet atau API kode dari Roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="Zm4bvMlEwsmRWr0VU3O6")
project = rf.workspace("aletta-workspace").project("pi_cucumber_leaf_disease-3")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in pi_cucumber_leaf_disease-3-1 to yolo26:: 100%|██████████| 62104/62104 [00:01<00:00, 35708.51it/s]
# Extracting Dataset Version Zip to pi_cucumber_leaf_disease-3-1 in yolo26:: 100%|██████████| 2315/2315 [00:00<00:00, 2975.74it/s]

# %% [markdown]
# #### BAGIAN 3: Menghubungkan Google Colab dengan Drive untuk Menyimpan Model Terbaik Saat Training

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### BAGIAN 4: Inisialisasi Arsitektur dan Mulai Training YOLO26m (run1_default)

# %%
import os
from ultralytics import YOLO

# 1. Inisialisasi model YOLO26m
model = YOLO("yolo26m.pt")

# 2. Folder penyimpanan hasil training
save_directory = "/content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/FIX TANPA HYPERPARAMETER-DEFAULT YOLO26"
os.makedirs(save_directory, exist_ok=True)

# 3. Training dengan konfigurasi default YOLO26m
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=200,
    imgsz=640,
    batch=16,
    device=0,
    project=save_directory,
    name="run1_default"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26m.pt to 'yolo26m.pt': 100% ━━━━━━━━━━━━ 42.2MB 303.9MB/s 0.1s
# Ultralytics 8.4.80 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/pi_cucumber_leaf_disease-3-1/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=200, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=run1_default, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/FIX TANPA HYPERPARAMETER-DEFAULT YOLO26, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/FIX TANPA HYPERPARAMETER-DEFAULT YOLO26/run1_default, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 23.7MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   2803242  ultralytics.nn.modules.head.Detect           [3, 1, True, [256, 512, 512]]
# YOLO26m summary: 280 layers, 21,777,514 parameters, 21,777,514 gradients, 74.7 GFLOPs
#
# Transferred 756/768 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 106.8MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1140.3±488.4 MB/s, size: 51.9 KB)
# train: Scanning /content/pi_cucumber_leaf_disease-3-1/train/labels... 1011 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1011/1011 1.9Kit/s 0.5s
# train: New cache created: /content/pi_cucumber_leaf_disease-3-1/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.1 ms, read: 841.2±513.7 MB/s, size: 46.1 KB)
# val: Scanning /content/pi_cucumber_leaf_disease-3-1/valid/labels... 95 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 95/95 1.4Kit/s 0.1s
# val: New cache created: /content/pi_cucumber_leaf_disease-3-1/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
# Plotting labels to /content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/FIX TANPA HYPERPARAMETER-DEFAULT YOLO26/run1_default/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/FIX TANPA HYPERPARAMETER-DEFAULT YOLO26/run1_default
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200      8.79G      1.288      3.017    0.01437         20        640: 100% ━━━━━━━━━━━━ 64/64 1.1it/s 57.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.7s/it 8.1s
#                    all         95        385      0.469       0.49      0.492      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/200      8.89G      1.386      1.717     0.0159         30        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.419      0.491      0.419      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/200      8.99G      1.435      1.539    0.01703         15        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.433      0.548      0.468      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/200      8.99G      1.455      1.481    0.01737         27        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.579      0.363      0.458      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/200      8.98G      1.437       1.43    0.01703         20        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.678      0.532      0.605       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/200         9G      1.416       1.37    0.01642         17        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.736      0.634      0.639       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/200         9G      1.361      1.297    0.01613         24        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385       0.53      0.641      0.613      0.425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/200         9G      1.326      1.265    0.01546         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385       0.65      0.639      0.685      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/200      9.02G      1.301      1.232    0.01487         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.706      0.599      0.647      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/200      9.01G      1.273      1.214    0.01502         12        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.659      0.623      0.665      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/200         9G      1.276      1.193    0.01509         29        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.659      0.632      0.683      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/200      9.01G      1.211      1.158    0.01399         12        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.736      0.656      0.723       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/200         9G      1.202      1.132    0.01394         13        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.703      0.545      0.652      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/200      9.02G      1.197      1.158    0.01385         31        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.619      0.594      0.606      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/200      8.99G      1.181      1.126    0.01369         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385       0.61      0.676      0.667      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/200      8.99G       1.15       1.07    0.01299         28        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.739      0.677      0.735      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/200         9G      1.111      1.049    0.01275         10        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.677      0.671      0.693      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/200      8.99G      1.138      1.087    0.01267         22        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.707      0.688      0.712      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/200      8.99G      1.171      1.054    0.01323         22        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.723      0.715      0.772      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/200      9.02G      1.111      1.016    0.01252         28        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.644      0.681      0.713      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/200      9.02G      1.086      1.014    0.01226         24        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.796      0.701      0.765       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/200      9.01G      1.077     0.9886    0.01212         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.729      0.561       0.69      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/200      9.01G      1.089     0.9967    0.01239         19        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.701      0.713       0.75      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/200      9.01G       1.08     0.9637    0.01205         23        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.734      0.764      0.783      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/200         9G       1.05     0.9318    0.01195         28        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.731      0.676      0.753      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/200      9.02G      1.066     0.9417    0.01219         18        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.739      0.708      0.758      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/200         9G      1.041      0.977    0.01182         18        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.809      0.648      0.743      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/200         9G      1.026     0.9299    0.01136         17        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.664      0.636      0.694      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/200      9.02G      1.048     0.9444    0.01185         15        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.743      0.707      0.762      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/200         9G      1.006     0.8757    0.01151         32        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.721      0.704      0.764      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/200      9.02G      1.033     0.9088    0.01164         18        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.759      0.683      0.778      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/200      8.99G       1.01     0.8923     0.0117         23        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.816      0.657      0.758      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/200         9G      1.005     0.8928    0.01128         15        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.758      0.738      0.766      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/200         9G     0.9877     0.8782    0.01118         37        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.696      0.697      0.738      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/200         9G       1.01     0.8801     0.0113          9        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385       0.81      0.658      0.774      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/200      9.03G      1.001     0.8759    0.01121         26        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.694      0.723      0.757      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/200         9G     0.9851      0.836    0.01107         13        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.763      0.679      0.768      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/200         9G      0.982     0.8645    0.01071         26        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.688      0.748      0.744      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/200      8.99G      0.979      0.835    0.01102         12        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.768      0.603      0.719      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/200      8.99G     0.9578     0.8101     0.0105         24        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.766      0.653      0.738      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/200         9G     0.9489     0.8316     0.0106         26        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.695      0.687      0.744      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/200      8.99G      0.971     0.8479    0.01088         24        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.738      0.676      0.739      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/200      9.02G     0.9455     0.8177    0.01063         13        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.767      0.669       0.78      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/200      9.02G      0.933     0.8131    0.01036         28        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.766      0.667      0.753       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/200         9G     0.9444     0.8147    0.01066         18        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.755      0.679      0.749      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/200         9G     0.9163     0.7877    0.01017         24        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.791      0.675      0.776       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/200      8.99G     0.9342     0.7845    0.01025         22        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385       0.84      0.681      0.793      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/200         9G      0.907     0.7867   0.009838         33        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.729      0.685      0.752      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/200      9.02G     0.9164     0.7914    0.01021         11        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.753      0.719      0.768      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/200      8.99G     0.9424     0.8041    0.01033         30        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.752      0.696      0.779       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/200         9G       0.93     0.7594    0.01032         21        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.752      0.669      0.771      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/200      9.02G     0.9078     0.7351   0.009834         41        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385       0.82      0.654      0.751      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/200      9.01G     0.8987     0.7291   0.009944         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.754      0.689      0.762      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/200         9G     0.9013     0.7498    0.01005         15        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.792      0.657      0.756      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/200      8.99G     0.8867     0.7298    0.00958         19        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.741      0.732      0.758      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/200      9.01G      0.896     0.7287   0.009792         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385       0.77      0.684      0.763      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/200         9G      0.902     0.7255   0.009764         13        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.745      0.747      0.788      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/200      8.99G     0.8717      0.698   0.009845         17        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.728      0.779      0.787      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/200      9.02G     0.8855     0.7228   0.009623         24        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.727      0.751      0.789      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/200      9.01G       0.89     0.7299    0.00994         20        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.725      0.726      0.792      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/200      8.99G     0.8542     0.6768   0.009358         19        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.776      0.726      0.799      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/200      8.98G      0.868     0.7085   0.009711         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385       0.74      0.731      0.784      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/200         9G     0.8687     0.7023   0.009516         11        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.741      0.702      0.775      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/200      8.99G     0.8781     0.6847   0.009587         26        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.727      0.718      0.764      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/200      9.01G     0.8539     0.6753   0.009354         11        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.849      0.646       0.76      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/200      9.01G     0.8526     0.7059    0.00934         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.782        0.7      0.758       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/200      8.99G     0.8608     0.6781   0.009495         16        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385       0.75      0.711       0.77      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/200      9.02G     0.8367     0.6394   0.009122         29        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385       0.78      0.724      0.785      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/200      9.02G     0.8462     0.6462   0.009213         20        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.789        0.7      0.757      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/200      8.99G     0.8366     0.6471   0.009125         20        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.804      0.703       0.79      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/200      8.99G     0.8251     0.6399   0.008892         30        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.721      0.727      0.766      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/200      9.02G     0.8229     0.6527   0.008925         15        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.795       0.67      0.762      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/200      9.01G     0.8268      0.667   0.009012         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.756      0.712      0.777      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/200      8.98G     0.8077     0.6154   0.008648         29        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.751      0.655      0.739      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/200      9.01G     0.8159     0.6244   0.009135         26        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.778      0.644      0.747      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/200      8.99G     0.8034     0.6205   0.008677         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.7s
#                    all         95        385      0.707      0.737       0.77      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/200      8.99G     0.8031      0.595   0.008838         16        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.796      0.679      0.738      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/200         9G     0.8068     0.6258   0.008842         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.805      0.725      0.794      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/200      8.99G     0.8139     0.6261   0.009133         26        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.764      0.724      0.782      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/200         9G     0.7887     0.5668   0.008397         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.719      0.729      0.753      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/200      9.02G     0.8062     0.6123    0.00872         18        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.822      0.735      0.808      0.679
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/200      8.99G     0.7862     0.5927   0.008703         29        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.825      0.741      0.803      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/200         9G     0.7878     0.5864   0.008685         26        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.772      0.753      0.789      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/200      8.99G     0.7861     0.5681   0.008287         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.718      0.771      0.779      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/200      8.99G     0.7752     0.5744   0.008391         35        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.779      0.728      0.769      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/200      9.02G     0.7736     0.5618   0.008339         36        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.776      0.731      0.782      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/200         9G     0.7668     0.5533   0.008228         21        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.807      0.733      0.792      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/200      9.01G     0.7766     0.5844   0.008586         18        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.851      0.691      0.773      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/200         9G     0.7636     0.5658   0.008216         10        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.797      0.703      0.765      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/200      9.01G     0.7741     0.5617   0.008583         15        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.783       0.73      0.771      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/200         9G     0.7706      0.574   0.008432         12        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.803      0.669      0.768      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/200      8.97G     0.7645     0.5459   0.008479         36        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385       0.77      0.704      0.779      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/200      9.02G     0.7447     0.5251   0.008205         37        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.799        0.7      0.774      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/200      8.99G     0.7564     0.5374   0.008323         15        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.838      0.666      0.782      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/200         9G     0.7426     0.5375   0.008167         20        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.776      0.701      0.764      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/200         9G     0.7409     0.5463   0.008285         19        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.795      0.685      0.786      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/200         9G     0.7388      0.537   0.008263         13        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.774      0.664      0.762      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/200         9G     0.7413     0.5314    0.00808         19        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.716      0.749      0.775      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/200      9.02G     0.7295     0.5266   0.007968         16        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.735      0.728      0.772      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# ...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     166/200         9G     0.5458     0.3503   0.005839         21        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.789      0.744      0.775      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     167/200         9G     0.5447     0.3345   0.005718         15        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.777      0.732      0.769      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     168/200      8.99G     0.5407     0.3607    0.00585         30        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 40.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.785      0.728      0.757      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     169/200      9.01G     0.5447     0.3463   0.005637         17        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.811      0.687      0.753       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     170/200         9G     0.5489      0.346   0.006015         12        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.811      0.701       0.76      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     171/200         9G     0.5425     0.3402   0.005708         31        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.789      0.725      0.764      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     172/200         9G     0.5322     0.3288   0.005669         16        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.769      0.731      0.772      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     173/200      9.02G     0.5378     0.3361   0.005636         32        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.765      0.741      0.776      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     174/200      9.02G     0.5338     0.3381   0.005581         25        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.764      0.743      0.783      0.665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     175/200         9G       0.53     0.3319   0.005419         17        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 40.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.841      0.693      0.778      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     176/200         9G     0.5358     0.3347   0.005675         28        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.832      0.697      0.761      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     177/200      9.01G     0.5268     0.3344   0.005469         17        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.837      0.696      0.767      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     178/200      8.99G     0.5292     0.3338   0.005578         28        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.829      0.713      0.771      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     179/200      9.02G     0.5337     0.3272   0.005572         28        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385       0.84      0.706      0.762      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     180/200         9G     0.5338     0.3282   0.005519         23        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.806      0.722      0.765       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     181/200      8.99G     0.5089     0.3242   0.005316         28        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.854      0.711      0.771      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     182/200      8.99G     0.5227     0.3287   0.005483         13        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385       0.86      0.692      0.771      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     183/200      8.99G     0.5055     0.3138   0.005343         10        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 40.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.854      0.682      0.761      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     184/200         9G     0.5102     0.3216   0.005292         25        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.768      0.745      0.764      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     185/200      8.99G     0.5295     0.3397   0.005635         14        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.824      0.716      0.769      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     186/200      8.99G     0.5234     0.3359   0.005514         22        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.808      0.726      0.764      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     187/200         9G     0.5095     0.3253   0.005428         15        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.825      0.729      0.765      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     188/200      9.02G     0.5117     0.3214   0.005396         14        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.844       0.72      0.768      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     189/200         9G     0.5295     0.3199    0.00563         10        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.824      0.732      0.769      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     190/200         9G     0.5135     0.3161   0.005347         15        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 41.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.783      0.746      0.767      0.651
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     191/200      8.96G     0.5132     0.2564   0.006753         14        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.843       0.72      0.776       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     192/200      8.96G     0.5056     0.2666   0.006907         11        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.828      0.725      0.765       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     193/200      8.96G      0.484     0.2383   0.006383         10        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.5s
#                    all         95        385      0.836      0.722       0.77      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     194/200      8.96G     0.4585     0.2235   0.005928         12        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.829      0.719      0.776      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     195/200      8.96G     0.4497     0.2225   0.006147         11        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.785      0.743      0.772      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     196/200      8.95G     0.4791     0.2377   0.006346         13        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.787      0.738       0.77      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     197/200      8.96G     0.4469     0.2101   0.005901         10        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.774      0.741      0.775      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     198/200      8.96G     0.4376     0.2096   0.005602         11        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 40.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.838      0.688      0.773       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     199/200      8.98G      0.452     0.2207   0.006009         11        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 40.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.828      0.683      0.769      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     200/200      8.96G     0.4453     0.2247   0.005805         12        640: 100% ━━━━━━━━━━━━ 64/64 1.6it/s 41.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.0it/s 1.5s
#                    all         95        385      0.832      0.682      0.769      0.642
#
# 200 epochs completed in 2.480 hours.
# Optimizer stripped from /content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/FIX TANPA HYPERPARAMETER-DEFAULT YOLO26/run1_default/weights/last.pt, 44.0MB
# Optimizer stripped from /content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/FIX TANPA HYPERPARAMETER-DEFAULT YOLO26/run1_default/weights/best.pt, 44.0MB
#
# Validating /content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/FIX TANPA HYPERPARAMETER-DEFAULT YOLO26/run1_default/weights/best.pt...
# Ultralytics 8.4.80 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26m summary (fused): 132 layers, 20,351,765 parameters, 0 gradients, 67.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.0it/s 3.0s
#                    all         95        385      0.803       0.76      0.817      0.687
#           Embun_Tepung         71        139      0.765      0.906      0.909      0.772
#               Nekrosis         28         47      0.814      0.596      0.717       0.58
#                  Sehat         84        199       0.83      0.779      0.824      0.709
# Speed: 0.2ms preprocess, 13.9ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/FIX TANPA HYPERPARAMETER-DEFAULT YOLO26/run1_default

# %% [markdown]
# #### BAGIAN 5: Evaluasi Performa Model (Visualisasi Metrik) Dengan YOLO26m

# %%
import os
from IPython.display import display, Image

# Jalur folder hasil training di Google Drive
run_dir = '/content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/FIX TANPA HYPERPARAMETER-DEFAULT YOLO26/run1_default'

print("--- MENAMPILKAN HASIL EVALUASI MODEL ---")

# 1. Menampilkan Confusion Matrix (Melihat akurasi deteksi per kelas penyakit)
confusion_matrix_path = os.path.join(run_dir, 'confusion_matrix.png')
if os.path.exists(confusion_matrix_path):
    print("\n[1] Confusion Matrix:")
    display(Image(filename=confusion_matrix_path, width=600))

# 2. Menampilkan Grafik Progress Results (Melihat penurunan Loss dan kenaikan mAP per Epoch)
results_plot_path = os.path.join(run_dir, 'results.png')
if os.path.exists(results_plot_path):
    print("\n[2] Grafik Perkembangan Training (Loss & mAP):")
    display(Image(filename=results_plot_path, width=800))
# Out:
# --- MENAMPILKAN HASIL EVALUASI MODEL ---
#
# [1] Confusion Matrix:
# [2] Grafik Perkembangan Training (Loss & mAP):

# %% [markdown]
# #### BAGIAN 6: Uji Coba Deteksi (Inference) Dengan Grid 2×5 Dengan YOLO26m

# %%
import glob
import os
import matplotlib.pyplot as plt
import cv2
from ultralytics import YOLO


# 1. Muat model yang tersimpan di GDrive
best_model_path = '/content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/FIX TANPA HYPERPARAMETER-DEFAULT YOLO26/run1_default/weights/best.pt'
model_best = YOLO(best_model_path)

# 3. Ambil seluruh sampel gambar dari folder DATA INFERENCE di GDrive
inference_folder_path = '/content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/DATA INFERENCE/*.jpg'
test_images = glob.glob(inference_folder_path)

print(f"--- MENJALANKAN DETEKSI GRID PADA {len(test_images)} GAMBAR INFERENCE ---")

# 4. Setup Grid Plot disesuaikan untuk 10 gambar (2 baris x 5 kolom)
fig, axes = plt.subplots(2, 5, figsize=(20, 8))
axes = axes.flatten()

for i, img_path in enumerate(test_images):
    # Prediksi
    results = model_best.predict(source=img_path, conf=0.50, verbose=False)

    # Ambil hasil plot (gambar yang sudah ada bounding box)
    res_plotted = results[0].plot()

    # Konversi BGR ke RGB untuk matplotlib
    res_plotted = cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB)

    # Tampilkan di grid
    axes[i].imshow(res_plotted)
    axes[i].axis('off')
    axes[i].set_title(f"Img {i+1}", fontsize=10)

# Menghapus sumbu koordinat jika ada sisa grid ax yang kosong
for j in range(len(test_images), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# --- MENJALANKAN DETEKSI GRID PADA 10 GAMBAR INFERENCE ---
