# %% [markdown]
# ### PI NADYA PUTRI NUR ALETTA (51423061)
# ### DETEKSI PENYAKIT DAUN MENTIMUN MENGGUNAKAN MODEL YOLO26m

# %% [markdown]
# #### BAGIAN 1: Verifikasi GPU dan Install Dependencies

# %%
# 1. Cek apakah GPU NVIDIA sudah aktif
# !nvidia-smi
# Out:
# Sun Jun 28 09:46:25 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# 2. Install library Ultralytics untuk eksekusi YOLO dan Roboflow untuk mengambil data
# !pip install ultralytics roboflow
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.80-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 2.7 MB/s eta 0:00:00
# Collecting roboflow
#   Downloading roboflow-1.3.10-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2026.5.20)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.0)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.3 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.3)
# Requirement already satisfied: requests_toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typer<0.26,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.25.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (8.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)
# Downloading ultralytics-8.4.80-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.9 MB/s eta 0:00:00
# Downloading roboflow-1.3.10-py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 26.5 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.8 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.8 MB/s eta 0:00:00
# Downloading pi_heif-1.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 88.9 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 144.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: pillow-avif-plugin, filetype, pi-heif, opencv-python-headless, idna, roboflow, ultralytics-thop, ultralytics
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.18
#     Uninstalling idna-3.18:
#       Successfully uninstalled idna-3.18
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.4.0 pillow-avif-plugin-1.5.5 roboflow-1.3.10 ultralytics-8.4.80 ultralytics-thop-2.0.20

# %% [markdown]
# #### BAGIAN 2: Mengunduh Dataset dari Roboflow

# %%
from roboflow import Roboflow

# Snippet atau API kode dari Roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="Zm4bvMlEwsmRWr0VU3O6")
project = rf.workspace("aletta-workspace").project("pi_cucumber_leaf_disease-3")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in pi_cucumber_leaf_disease-3-1 to yolo26:: 100%|██████████| 62104/62104 [00:01<00:00, 33051.85it/s]
# Extracting Dataset Version Zip to pi_cucumber_leaf_disease-3-1 in yolo26:: 100%|██████████| 2315/2315 [00:00<00:00, 4827.76it/s]

# %% [markdown]
# #### BAGIAN 3: Menghubungkan Google Colab dengan Drive untuk Menyimpan Model Terbaik Saat Training

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### BAGIAN 4: Inisialisasi Arsitektur dan Mulai Training YOLO26m (v2_training_run3)

# %%
import os
from ultralytics import YOLO

# 1. Inisialisasi model YOLO26m
model = YOLO('yolo26m.pt')

# 2. Jalur folder penyimpanan di Google Drive
save_directory = '/content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/BEST MODEL YOLO26n-v3'
os.makedirs(save_directory, exist_ok=True)

# 3. Mulai proses training dengan Early Stopping dan GDrive
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=200,            # Naikkan jadi 200 (karena model lebih besar butuh lebih lama belajar)
    imgsz=640,
    batch=16,
    device=0,
    patience=50,           # Early stopping aktif (patience 50 epoch)
    mosaic=1.0,            # Pastikan mosaic aktif (default 1.0)
    mixup=0.2,             # Tambahkan mixup (mencampur 2 gambar menjadi 1)
    degrees=15.0,          # Rotasi daun
    flipud=0.5,             # Flip vertikal
    lr0=0.001,
    project=save_directory,   # Otomatis tersimpan ke folder BEST MODEL YOLO26n-v3 di GDrive
    name='v2_training_run3'   # Hasil training akan tersimpan di dalam folder 'v2_training_run2'
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26m.pt to 'yolo26m.pt': 100% ━━━━━━━━━━━━ 42.2MB 116.8MB/s 0.4s
# Ultralytics 8.4.80 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/pi_cucumber_leaf_disease-3-1/data.yaml, degrees=15.0, deterministic=True, device=0, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=200, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.5, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolo26m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=v2_training_run3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=50, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/BEST MODEL YOLO26n-v3, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/BEST MODEL YOLO26n-v3/v2_training_run3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 27.3MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   2803242  ultralytics.nn.modules.head.Detect           [3, 1, True, [256, 512, 512]]
# YOLO26m summary: 280 layers, 21,777,514 parameters, 21,777,514 gradients, 74.7 GFLOPs
#
# Transferred 756/768 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 110.7MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1321.6±619.1 MB/s, size: 51.9 KB)
# train: Scanning /content/pi_cucumber_leaf_disease-3-1/train/labels... 1011 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1011/1011 2.1Kit/s 0.5s
# train: New cache created: /content/pi_cucumber_leaf_disease-3-1/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 929.1±526.1 MB/s, size: 46.1 KB)
# val: Scanning /content/pi_cucumber_leaf_disease-3-1/valid/labels... 95 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 95/95 1.6Kit/s 0.1s
# val: New cache created: /content/pi_cucumber_leaf_disease-3-1/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
# Plotting labels to /content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/BEST MODEL YOLO26n-v3/v2_training_run3/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/BEST MODEL YOLO26n-v3/v2_training_run3
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200      8.81G      1.538      3.134    0.02022         21        640: 100% ━━━━━━━━━━━━ 64/64 1.1it/s 58.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.8s/it 8.3s
#                    all         95        385      0.355      0.439      0.355      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/200       8.9G      1.531       1.91    0.01999         38        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 42.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.625       0.48      0.535      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/200      8.98G      1.609      1.771    0.02242         17        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.417      0.441       0.45      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/200         9G      1.605      1.722    0.02227         29        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.482      0.535       0.52      0.149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/200      8.99G      1.547      1.635     0.0206         20        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.615      0.494      0.551       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/200      8.98G      1.551      1.618     0.0209         23        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.589      0.615       0.59      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/200      9.02G      1.521      1.525    0.02035         23        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.561       0.62      0.608      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/200      9.03G      1.508      1.487    0.01987         47        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.568      0.501      0.522      0.252
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/200      9.02G      1.505      1.499    0.01944         39        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.521      0.624      0.611      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/200      9.01G      1.473      1.489    0.01959         40        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.678      0.613       0.66      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/200      9.03G      1.476      1.505     0.0196         26        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.595      0.665      0.637      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/200      9.02G      1.459       1.46    0.01971         26        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.678      0.644      0.674        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/200      9.03G      1.443      1.394    0.01911         22        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.606      0.651      0.644      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/200      9.02G      1.426      1.412    0.01867         14        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385       0.73      0.663       0.73      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/200         9G      1.414      1.365     0.0186         40        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 45.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.714      0.575      0.656      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/200      9.01G      1.406      1.345    0.01839         23        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.747      0.605      0.675      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/200      9.02G      1.389      1.339    0.01844         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.746      0.598      0.687      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/200      8.99G      1.391      1.317    0.01818         17        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.715      0.666      0.715      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/200      9.03G      1.413      1.357    0.01809         18        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.732      0.632      0.724      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/200      9.02G       1.39      1.347    0.01832         24        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.804      0.624      0.747      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/200      9.02G      1.362      1.306    0.01761         49        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.729      0.655      0.711      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/200      9.02G      1.364      1.322    0.01796         12        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.685      0.644      0.695      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/200      9.03G      1.367      1.315     0.0177         34        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.705      0.618      0.698      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/200      9.01G      1.336      1.296    0.01745         28        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.684      0.692      0.718      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/200      8.98G       1.37      1.281    0.01789         23        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.688      0.587       0.67      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/200         9G       1.38      1.281    0.01785         23        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.8s
#                    all         95        385       0.67      0.662      0.697      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/200      9.01G      1.335      1.264    0.01702         23        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.646      0.762       0.77      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/200      9.01G       1.34      1.235    0.01682         30        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 45.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.699      0.698      0.735      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/200      9.01G       1.32       1.23    0.01698         15        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.648      0.704      0.724       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/200      9.02G        1.3      1.254    0.01703         17        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.721      0.693      0.754      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/200      9.04G      1.298      1.204     0.0169         22        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.671      0.636      0.713       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/200      9.02G      1.315      1.201    0.01685         19        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.752      0.717      0.762      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/200      9.01G      1.283      1.196    0.01651         29        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385       0.69      0.683      0.745      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/200      9.02G      1.319      1.235    0.01696         28        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.697      0.681      0.735      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/200      9.02G      1.278      1.168    0.01644         36        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.7s
#                    all         95        385       0.81      0.658      0.767      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/200      9.01G      1.298      1.174    0.01687         23        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 45.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.743       0.71      0.763      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/200      9.01G      1.265      1.189    0.01636         19        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.729      0.665      0.734      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/200      9.03G       1.25      1.146    0.01582         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.732      0.636      0.726      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/200      9.01G      1.289      1.209    0.01691         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.746      0.636      0.734      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/200      8.99G      1.253       1.15    0.01618         22        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.723      0.657      0.757      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/200      8.99G      1.245      1.146    0.01622         19        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.7s
#                    all         95        385      0.726      0.698      0.752      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/200      9.02G      1.232      1.148    0.01595         20        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385       0.75      0.699      0.772      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/200      8.98G      1.214      1.126    0.01551         22        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.756       0.72      0.775      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/200      9.01G      1.226      1.123    0.01575         24        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.826      0.637      0.752      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/200      8.98G      1.232      1.107    0.01605         11        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.7s
#                    all         95        385      0.675      0.733      0.727      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/200      9.02G      1.226      1.135    0.01621         26        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.736      0.687      0.776        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/200      8.98G      1.212       1.11    0.01572         32        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.737      0.623      0.717      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/200      8.99G      1.222      1.118     0.0159         18        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.742      0.728      0.771      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/200      9.05G      1.233      1.103     0.0155         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.713      0.732      0.777      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/200      9.03G      1.279      1.126    0.01662         26        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.696      0.664      0.758      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/200      9.03G      1.235      1.086    0.01572         20        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.765      0.731      0.787      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/200      9.01G      1.169      1.076    0.01497         16        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.703      0.712      0.727      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/200      9.04G      1.191      1.061    0.01487         23        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.702      0.726      0.749      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/200      9.01G      1.206      1.066    0.01562         33        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.763      0.655      0.752      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/200      9.01G      1.185      1.046    0.01518         22        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.777      0.639      0.738      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/200      9.02G      1.194      1.071    0.01525         19        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.8s
#                    all         95        385      0.737      0.708      0.757      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/200      9.03G      1.168       1.09    0.01499         22        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.734      0.664      0.734      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/200      9.02G      1.167      1.068    0.01478         37        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.743       0.75      0.788      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/200      9.01G      1.159      1.027    0.01483         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.757      0.681      0.772      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/200      9.01G      1.165      1.038    0.01477         19        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.701      0.714      0.732      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/200      9.01G      1.158      1.025    0.01476         22        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385       0.72      0.718      0.762        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/200      9.02G      1.151     0.9982    0.01464         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.781      0.717      0.782      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/200      9.03G      1.146      1.034     0.0148         23        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.754      0.747      0.767      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/200      9.02G      1.149     0.9974    0.01477         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.756      0.622      0.701      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/200      9.03G       1.16      1.026    0.01464         46        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.724      0.743      0.781      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/200      8.99G      1.129     0.9965    0.01429         37        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.736      0.633      0.738      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/200      9.02G       1.15      1.002    0.01446         26        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385       0.76      0.704      0.769      0.603
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/200      9.02G      1.145     0.9544    0.01436         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.772      0.609      0.728      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/200      9.01G       1.13       1.01    0.01461         25        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.818      0.672      0.786      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/200      8.97G      1.121      1.007    0.01409         32        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.772      0.666      0.773      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/200      9.03G      1.104     0.9697    0.01378         22        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.767      0.679      0.754      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/200      9.01G      1.143     0.9962    0.01438         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.743      0.717      0.766      0.607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/200      8.99G      1.101     0.9635    0.01406         15        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.718      0.695      0.752      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/200      8.99G        1.1      0.966     0.0136         19        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.714       0.66      0.726      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/200      9.03G      1.102     0.9544    0.01376         31        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.749      0.632       0.74      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/200      9.03G      1.111     0.9672    0.01418         37        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.759      0.714      0.774      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/200      8.97G      1.119      0.988    0.01428         25        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.736      0.717      0.781      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/200      9.01G      1.103     0.9686    0.01421         22        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.709      0.685      0.762      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/200      9.01G      1.109     0.9687    0.01451         26        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.712      0.704      0.749      0.597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/200      9.05G      1.106     0.9568    0.01408         25        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385       0.86      0.622      0.762      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/200         9G      1.125     0.9601    0.01386         35        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.797      0.592      0.719      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/200      9.01G      1.128     0.9866    0.01436         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.734       0.71      0.783      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/200      9.04G      1.093     0.9453    0.01383         15        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 45.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385       0.79      0.669      0.763       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/200      9.02G      1.088     0.9176    0.01399         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.796      0.677       0.78      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/200      9.03G      1.092     0.9403      0.014         16        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.631      0.706      0.719       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/200         9G      1.075     0.9387    0.01362         37        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.723      0.691      0.754      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/200      9.02G        1.1     0.9374    0.01397         31        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.706       0.72      0.726       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/200      9.03G      1.067     0.8712     0.0131         23        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.7s
#                    all         95        385      0.775      0.669      0.737      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/200      8.99G      1.047     0.8792    0.01303         31        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.796       0.62      0.739      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/200      9.03G      1.035     0.8997    0.01299         15        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.696      0.708      0.748        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/200      9.01G      1.076     0.9133    0.01347         25        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.788      0.687      0.752      0.603
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/200      9.01G      1.031     0.8527    0.01296         24        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.778      0.625       0.72      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/200      8.98G      1.037     0.8723    0.01275         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.714      0.687      0.757      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/200      8.99G      1.074     0.8857    0.01362         24        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.7s
#                    all         95        385      0.781      0.709      0.779      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/200      9.03G      1.059     0.8701    0.01329         16        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.819      0.669      0.765      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/200      9.02G      1.039      0.871    0.01354         10        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.737      0.723       0.76      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/200      9.01G      1.037     0.8542    0.01322         15        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.804      0.693      0.761      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/200      9.03G      1.047     0.8536    0.01285         17        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.766      0.684      0.747      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/200      9.01G      1.027     0.8695    0.01283         33        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.693      0.682      0.736      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/200      9.01G      1.023     0.8577    0.01275         22        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.1s
# ...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     123/200      9.03G     0.9823     0.7952    0.01251         31        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385       0.74      0.742      0.791      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     124/200      9.03G      0.979     0.7843    0.01216         28        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.766       0.69      0.773      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     125/200      8.99G     0.9816     0.7718    0.01216         24        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.783      0.708      0.781      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     126/200      9.03G     0.9588     0.7731     0.0119         23        640: 100% ━━━━━━━━━━━━ 64/64 1.4it/s 44.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.719      0.755       0.79      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     127/200      9.03G     0.9538     0.7425    0.01202         26        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.8s
#                    all         95        385      0.767      0.726      0.783      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     128/200      9.02G     0.9567     0.7258    0.01167         36        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.7s
#                    all         95        385      0.768      0.747      0.772      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     129/200      9.01G      0.972     0.7687    0.01197         30        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.777      0.685      0.765      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     130/200      9.01G     0.9441     0.7485    0.01164         37        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.743       0.71      0.762      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     131/200      9.01G     0.9263     0.7391    0.01125         22        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385        0.8      0.638      0.752      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     132/200         9G     0.9569     0.7668    0.01189         11        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.713      0.721       0.75      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     133/200      9.03G     0.9525     0.7505    0.01182         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.713      0.732      0.764      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     134/200      9.02G     0.9359     0.7336    0.01166         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.8s
#                    all         95        385      0.808      0.707      0.777      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     135/200      8.99G     0.9234     0.7256    0.01139         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.6s
#                    all         95        385      0.739      0.685      0.761      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     136/200      9.03G     0.9266     0.7048    0.01157         34        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.729      0.709      0.736        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     137/200         9G      0.908     0.7261    0.01097         40        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.785      0.693      0.756       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     138/200         9G     0.9169     0.7215    0.01123         39        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.705      0.753       0.77      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     139/200      8.99G     0.9098     0.7251    0.01132         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.807      0.658      0.765      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     140/200      9.01G     0.9288     0.7345    0.01153         34        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.863      0.648      0.768       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     141/200      8.99G     0.9263     0.7199    0.01135         24        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.7s
#                    all         95        385      0.838       0.66      0.751      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     142/200      9.03G     0.8958     0.6913    0.01075         35        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.795      0.686      0.753      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     143/200      8.99G     0.9145     0.6872    0.01116         47        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.825      0.649      0.761      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     144/200      9.03G     0.9037     0.7025    0.01119         38        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.822      0.659      0.763      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     145/200      9.02G     0.9114      0.708    0.01107         71        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.751      0.679      0.747      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     146/200      9.02G     0.9239     0.7323    0.01167         13        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385       0.73      0.697      0.745      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     147/200      9.01G      0.887     0.6794     0.0107         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.812      0.669      0.758      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     148/200      9.03G     0.9022     0.6766    0.01118         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.771      0.686      0.751       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     149/200      9.01G     0.9089     0.6911    0.01128         23        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.744      0.693      0.746      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     150/200      9.04G      0.914     0.7042    0.01144         17        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.801      0.696      0.745      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     151/200      9.01G     0.8841     0.6772    0.01104         37        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.769      0.695      0.751      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     152/200      8.99G     0.8872     0.6886    0.01106         21        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.802      0.689      0.761      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     153/200      9.03G      0.897     0.7016    0.01118         47        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.815      0.665      0.761      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     154/200      9.03G     0.8799     0.6685    0.01056         27        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.816      0.672      0.758      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     155/200      9.02G     0.8733     0.6577    0.01062         18        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 43.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.8it/s 1.7s
#                    all         95        385      0.863      0.655      0.766      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     156/200      9.01G     0.8651     0.6818    0.01081         34        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.7it/s 1.7s
#                    all         95        385       0.79      0.672      0.735      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     157/200      9.02G     0.8603     0.6553    0.01057         56        640: 100% ━━━━━━━━━━━━ 64/64 1.5it/s 44.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.9it/s 1.6s
#                    all         95        385      0.786      0.671      0.741      0.611
# EarlyStopping: Training stopped early as no improvement observed in last 50 epochs. Best results observed at epoch 107, best model saved as best.pt.
# To update EarlyStopping(patience=50) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 157 epochs completed in 2.067 hours.
# Optimizer stripped from /content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/BEST MODEL YOLO26n-v3/v2_training_run3/weights/last.pt, 44.0MB
# Optimizer stripped from /content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/BEST MODEL YOLO26n-v3/v2_training_run3/weights/best.pt, 44.0MB
#
# Validating /content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/BEST MODEL YOLO26n-v3/v2_training_run3/weights/best.pt...
# Ultralytics 8.4.80 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26m summary (fused): 132 layers, 20,351,765 parameters, 0 gradients, 67.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.0it/s 2.9s
#                    all         95        385      0.786      0.705      0.813      0.655
#           Embun_Tepung         71        139      0.783      0.835      0.892      0.739
#               Nekrosis         28         47      0.779      0.601      0.722      0.563
#                  Sehat         84        199      0.797      0.678      0.827      0.664
# Speed: 0.3ms preprocess, 14.3ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/BEST MODEL YOLO26n-v3/v2_training_run3

# %% [markdown]
# #### BAGIAN 5: Evaluasi Performa Model (Visualisasi Metrik) Dengan YOLO26m

# %%
import os
from IPython.display import display, Image

# Jalur folder hasil training di Google Drive
run_dir = '/content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/BEST MODEL YOLO26n-v3/v2_training_run3'

print("--- MENAMPILKAN HASIL EVALUASI MODEL ---")

# 1. Menampilkan Confusion Matrix (Melihat akurasi deteksi per kelas penyakit)
confusion_matrix_path = os.path.join(run_dir, 'confusion_matrix.png')
if os.path.exists(confusion_matrix_path):
    print("\n[1] Confusion Matrix:")
    display(Image(filename=confusion_matrix_path, width=600))

# 2. Menampilkan Grafik Progress Results (Melihat penurunan Loss dan kenaikan mAP per Epoch)
results_plot_path = os.path.join(run_dir, 'results.png')
if os.path.exists(results_plot_path):
    print("\n[2] Grafik Perkembangan Training (Loss & mAP):")
    display(Image(filename=results_plot_path, width=800))
# Out:
# --- MENAMPILKAN HASIL EVALUASI MODEL ---
#
# [1] Confusion Matrix:
# [2] Grafik Perkembangan Training (Loss & mAP):

# %% [markdown]
# #### BAGIAN 6: Uji Coba Deteksi (Inference) Dengan Grid 2×5 Dengan YOLO26m

# %%
import glob
import os
import matplotlib.pyplot as plt
import cv2
from ultralytics import YOLO


# 1. Muat model yang tersimpan di GDrive
best_model_path = '/content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/BEST MODEL YOLO26n-v3/v2_training_run3/weights/best.pt'
model_best = YOLO(best_model_path)

# 3. Ambil seluruh sampel gambar dari folder DATA INFERENCE di GDrive
inference_folder_path = '/content/drive/MyDrive/PI (PENULISAN ILMIAH SEMESTER 6) 2026/DATA INFERENCE/*.jpg'
test_images = glob.glob(inference_folder_path)

print(f"--- MENJALANKAN DETEKSI GRID PADA {len(test_images)} GAMBAR INFERENCE ---")

# 4. Setup Grid Plot disesuaikan untuk 10 gambar (2 baris x 5 kolom)
fig, axes = plt.subplots(2, 5, figsize=(20, 8))
axes = axes.flatten()

for i, img_path in enumerate(test_images):
    # Prediksi
    results = model_best.predict(source=img_path, conf=0.50, verbose=False)

    # Ambil hasil plot (gambar yang sudah ada bounding box)
    res_plotted = results[0].plot()

    # Konversi BGR ke RGB untuk matplotlib
    res_plotted = cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB)

    # Tampilkan di grid
    axes[i].imshow(res_plotted)
    axes[i].axis('off')
    axes[i].set_title(f"Img {i+1}", fontsize=10)

# Menghapus sumbu koordinat jika ada sisa grid ax yang kosong
for j in range(len(test_images), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
# Out:
# --- MENJALANKAN DETEKSI GRID PADA 10 GAMBAR INFERENCE ---
